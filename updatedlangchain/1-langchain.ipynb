# %% [markdown]
# ##this is the langhcian version v1

# %% [markdown]
# import os

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
os.environ["GOOGLE_API_KEY"]=os.getenv("Google_API_KEY")

# %%
from langchain.agents import create_agent

# %%
# agent=create_agent(
# model="gemini/gemini-2.0-flash",
# tools=[],
# system_prompt="you are an helpful assistant"

# )

# %%
from langchain.chat_models import init_chat_model ## you can us eany model like open ai etc
model = init_chat_model(
    "gemini-2.5-flash", 
    model_provider="google_genai",
    #api_key=os.getenv("GOOGLE_API_KEY") # Ensure this is provided
)

# %%
response = model.invoke("Hello, how are you?")

# %%
response
# Out:
# AIMessage(content="Hello! I'm functioning perfectly and ready to assist you.\n\nThank you for asking! How are you doing today?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bcca6-8f57-73f0-8d37-9da4ea655d9a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 185, 'total_tokens': 192, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 160}})

# %%
response.content
# Out:
# "Hello! I'm functioning perfectly and ready to assist you.\n\nThank you for asking! How are you doing today?"

# %%
# from google import genai

# client = genai.Client()

# response = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents="Hello, how are you"
# )
# print(response.text)
# Out:
# Hello! As an AI, I don't have feelings or a physical state, so I don't "feel" well or unwell in the human sense, but I'm online and ready to assist you.
#
# Thanks for asking! How are *you* doing today?

# %%
## why create agent & not regular init_chat
## create agent is used to call interact with others.
##  from google import genai  -- this is not using langchain.

# %%
updatedlangchain/
├── app.py
├── ui/
│   └── streamlit_app.py
├── agents/
│   └── main_agent.py
├── tools/
│   ├── retriever.py
│   ├── web_search.py
│   └── auth_tool.py   ← dummy auth
├── memory/
│   └── session_store.py
├── vectorstore/
│   └── chroma_db/
├── prompts/
│   └── agent_prompt.py
└── requirements.txt
